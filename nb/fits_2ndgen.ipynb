# %%
import os 
import sys

# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use(os.path.join(os.path.abspath(''), 'plot_style.mplstyle'))
plots_dir = '../../plots/'

from desilike.samples import Profiles, Chain, plotting
sys.path.append('../bin')
from emulator_fit import get_power_likelihood

# %%
tracer = 'ELG_LOP'
region = 'SGC'
data_dir = '/global/cfs/cdirs/desi/users/mpinon/secondGenMocksY1/'

template_name = 'shapefitqisoqap'

emulator_dir = os.path.join(data_dir, 'emulators/emulators_{}_{}'.format(template_name, tracer))

#data_type = 'rawY1secondgenmocks'
#chains_dir = os.path.join(data_dir, 'chains', data_type, 'chains_{}_{}_{{}}{}'.format(template_name, tracer, region))
#chain_raw = Chain.concatenate([Chain.load(os.path.join(chains_dir.format('complete_'), 'power_velocileptors_{:d}.npy'.format(i))).remove_burnin(0.5)[::10] for i in range(8)])

data_type = 'Y1secondgenmocks'
chains_dir = os.path.join(data_dir, 'chains', data_type, 'chains_{}_{}_{{}}{}'.format(template_name, tracer, region))
chain_masked = Chain.concatenate([Chain.load(os.path.join(chains_dir.format('complete_'), 'power_velocileptors_{:d}.npy'.format(i))).remove_burnin(0.5)[::10] for i in range(8)])

#chain_masked_mock0 = Chain.concatenate([Chain.load(os.path.join(chains_dir.format('complete_'), 'power_velocileptors_mock0_{:d}.npy'.format(i))).remove_burnin(0.5)[::10] for i in range(8)])

data_type = 'Y1secondgenmocks'
chains_dir = os.path.join(data_dir, 'chains', data_type, 'chains_{}_{}_{{}}{}'.format(template_name, tracer, region))
chain_masked_rpcut = Chain.concatenate([Chain.load(os.path.join(chains_dir.format('complete_'), 'power_velocileptors_rpcut2.5_directedges_{:d}.npy'.format(i))).remove_burnin(0.5)[::10] for i in range(8)])

#chain_masked_rpcut_mock0 = Chain.concatenate([Chain.load(os.path.join(chains_dir.format('complete_'), 'power_velocileptors_rpcut2.5_directedges_mock0_{:d}.npy'.format(i))).remove_burnin(0.5)[::10] for i in range(8)])

data_type = 'Y1secondgenmocks'
chains_dir = os.path.join(data_dir, 'chains', data_type, 'chains_{}_{}_{{}}{}'.format(template_name, tracer, region))
chain_masked_thetacut = Chain.concatenate([Chain.load(os.path.join(chains_dir.format('complete_'), 'power_velocileptors_thetacut0.06_directedges_{:d}.npy'.format(i))).remove_burnin(0.5)[::10] for i in range(8)])

data_type = 'Y1secondgenmocks'
chains_dir = os.path.join(data_dir, 'chains', data_type, 'chains_{}_{}_{{}}{}'.format(template_name, tracer, region))
chain_masked_rpcut_sculptwindow = Chain.concatenate([Chain.load(os.path.join(chains_dir.format('complete_'), 'power_velocileptors_rpcut2.5_directedges__sculptwindow{:d}.npy'.format(i))).remove_burnin(0.5)[::10] for i in range(8)])

data_type = 'Y1secondgenmocks'
chains_dir = os.path.join(data_dir, 'chains', data_type, 'chains_{}_{}_{{}}{}'.format(template_name, tracer, region))
chain_masked_rpcut_sculptwindow_gauspriors = Chain.concatenate([Chain.load(os.path.join(chains_dir.format('complete_'), 'power_velocileptors_rpcut2.5_directedges__sculptwindow_gauspriors{:d}.npy'.format(i))).remove_burnin(0.5)[::10] for i in range(8)])

data_type = 'Y1secondgenmocks'
chains_dir = os.path.join(data_dir, 'chains', data_type, 'chains_{}_{}_{{}}{}'.format(template_name, tracer, region))
chain_masked_rpcut_sculptwindow_gauspriors2000_100_20 = Chain.concatenate([Chain.load(os.path.join(chains_dir.format('complete_'), 'power_velocileptors_rpcut2.5_directedges__sculptwindow_gauspriors2000_100_20{:d}.npy'.format(i))).remove_burnin(0.5)[::10] for i in range(8)])

#data_type = 'Y1secondgenmocks'
#chains_dir = os.path.join(data_dir, 'chains', data_type, 'chains_{}_{}_{{}}{}'.format(template_name, tracer, region))
#chain_masked_lowres = Chain.concatenate([Chain.load(os.path.join(chains_dir.format('complete_'), 'power_velocileptors__lowres{:d}.npy'.format(i))).remove_burnin(0.5)[::10] for i in range(8)])

#data_dir = '/global/cfs/cdirs/desi/users/mpinon/cubicSecondGenMocks/'
#data_type = 'cubicsecondgenmocks'
#tracer = 'ELG'
#region = 'GCcomb'
#chains_dir = os.path.join(data_dir, 'chains', data_type, 'chains_{}_{}_{{}}{}'.format(template_name, tracer, region))
#chain_cubic = Chain.concatenate([Chain.load(os.path.join(chains_dir.format('complete_'), 'power_velocileptors_{:d}.npy'.format(i))).remove_burnin(0.5)[::10] for i in range(8)])

# %%
from getdist import plots
g = plots.get_single_plotter(width_inch=6, scaling=False, ratio=1)
g.settings.axes_fontsize = 12
g.settings.axes_labelsize = 12
#g.settings.solid_contour_palefactor = 0.9
#g.settings.alpha_filled_add = 0.3

# %%
markers = {'qiso': 1., 'qap': 1., 'df': 1., 'dm': 0.}
#params = ['qiso', 'qap', 'df', 'dm', 'b1', 'b2', 'bs', 'alpha0', 'alpha2', 'alpha4', 'sn0', 'sn2', 'sn4']
params = ['qiso', 'qap', 'df', 'dm', 'b1']
colors = ['dodgerblue', 'orangered', 'darkcyan']
plotting.plot_triangle([chain_masked, chain_masked_rpcut, chain_masked_rpcut_sculptwindow_gauspriors2000_100_20], labels=[r'No cut', r'$r_{\perp}$-cut', r'$r_{\perp}$-cut, $W^{\prime}$'], 
                       markers=markers, params=params,
                       g=g, lws=1.5, contour_lws=1.5, filled=False, colors=colors, contour_colors=colors, contour_ls=['-', '--', ':'],
                       legend_loc='upper right', 
                       show=False)
fig = plt.gcf()
fig.align_ylabels()
plt.savefig(os.path.join(plots_dir, 'corner_plot_rpcut_sculptwindow_{}_{}_{}.png'.format(tracer, 'SGC', 'power')), dpi=300)
plt.show()
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# /tmp/ipykernel_1349367/3004110379.py:12: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.savefig(os.path.join(plots_dir, 'corner_plot_rpcut_sculptwindow_{}_{}_{}.png'.format(tracer, 'SGC', 'power')), dpi=300)
# /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20231013-1.0.0/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plotting.plot_triangle([chain_masked_rpcut_sculptwindow, chain_masked_rpcut_sculptwindow_gauspriors], labels=[r'No prior', r'Gaussian prior'], 
                       markers=markers, params=['alpha0', 'alpha2', 'alpha4', 'sn0', 'sn2', 'sn4', 'syst_0', 'syst_1', 'syst_2'],
                       g=g, lws=1.5, contour_lws=1.5, filled=False, colors=colors, contour_colors=colors, contour_ls=['-', '--'],
                       legend_loc='upper right', 
                       show=False)
fig = plt.gcf()
fig.align_ylabels()
plt.show()
# Out:
# Removed no burn in
# Removed no burn in
# /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20231013-1.0.0/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
chain_masked_rpcut_sculptwindow.params
# Out:
# <bound method BaseParameterCollection.params of Chain(shape=(4320, 40), params=ParameterCollection(['syst_0', 'syst_1', 'syst_2', 'qiso', 'qap', 'dm', 'df', 'b1', 'b2', 'bs', 'logposterior', 'dn', 'b3', 'f_sqrt_Ap', 'm', 'n', 'loglikelihood', 'logprior', 'alpha0', 'alpha2', 'alpha4', 'sn0', 'sn2', 'sn4', 'aweight', 'fweight']))>

# %%
print(chain_masked_rpcut_sculptwindow.to_stats(params=['syst_0', 'syst_1', 'syst_2'], tablefmt='pretty'))
# Out:
# +--------+--------+------+--------+------+-----------------+-----------------+
# |        | argmax | mean | median | std  | quantile:1sigma | interval:1sigma |
# +--------+--------+------+--------+------+-----------------+-----------------+
# | syst_0 | -1000  | 200  |  100   | 3900 |   -3900/+3900   |   -3900/+3800   |
# | syst_1 |   70   | -190 |  -170  | 370  |    -360/+360    |    -330/+390    |
# | syst_2 |  -22   | -17  |  -17   |  97  |     -97/+97     |    -94/+100.    |
# +--------+--------+------+--------+------+-----------------+-----------------+

# %%
chain_masked_rpcut_sculptwindow['sn2'].param.prior
# Out:
# norm({'loc': 0.0, 'scale': 50.0})

# %%
print(chain_masked_rpcut_sculptwindow.sample_solved().to_stats(params=['sn0', 'sn2', 'sn4'], tablefmt='pretty'))
# Out:
# +-----+--------+-------+--------+------+-----------------+-----------------+
# |     | argmax | mean  | median | std  | quantile:1sigma | interval:1sigma |
# +-----+--------+-------+--------+------+-----------------+-----------------+
# | sn0 | -0.35  | -0.22 | -0.21  | 0.46 |   -0.46/+0.46   |   -0.44/+0.48   |
# | sn2 |  3.9   |  3.0  |  2.8   | 7.2  |    -7.1/+7.1    |    -7.6/+6.6    |
# | sn4 |   -1   |  -8   |   -8   |  39  |     -39/+39     |    -39/+40.     |
# +-----+--------+-------+--------+------+-----------------+-----------------+

# %%
print(chain_masked_rpcut_sculptwindow_gauspriors.sample_solved().to_stats(params=['sn0', 'sn2', 'sn4'], tablefmt='pretty'))
# Out:
# +-----+--------+--------+--------+-------+-----------------+-----------------+
# |     | argmax |  mean  | median |  std  | quantile:1sigma | interval:1sigma |
# +-----+--------+--------+--------+-------+-----------------+-----------------+
# | sn0 | -0.045 | -0.056 | -0.052 | 0.081 |  -0.080/+0.081  |  -0.076/+0.084  |
# | sn2 |  -0.6  |  -0.5  |  -0.5  |  1.9  |    -1.9/+1.9    |    -2.0/+1.7    |
# | sn4 |  -10.  |   1    |   0.   |  30.  |    -30./+30.    |    -31/+30.     |
# +-----+--------+--------+--------+-------+-----------------+-----------------+

# %%
params = ['qiso', 'qap', 'df', 'dm', 'b1', 'b2', 'bs', 'alpha0', 'alpha2', 'alpha4', 'sn0', 'sn2', 'sn4']

# %%
chain_masked.params
# Out:
# <bound method BaseParameterCollection.params of Chain(shape=(1080, 40), params=ParameterCollection(['qiso', 'qap', 'dm', 'df', 'b1', 'b2', 'bs', 'logposterior', 'dn', 'b3', 'f_sqrt_Ap', 'm', 'n', 'loglikelihood', 'logprior', 'alpha0', 'alpha2', 'alpha4', 'sn0', 'sn2', 'sn4', 'aweight', 'fweight']))>

# %%
print(chain_masked.to_stats(params=params, tablefmt='pretty'))
# Out:
# +--------+--------+--------+--------+-------+-----------------+-----------------+
# |        | argmax |  mean  | median |  std  | quantile:1sigma | interval:1sigma |
# +--------+--------+--------+--------+-------+-----------------+-----------------+
# |  qiso  | 1.006  | 1.002  | 1.002  | 0.014 |  -0.014/+0.014  |  -0.015/+0.013  |
# |  qap   | 0.994  | 1.001  | 1.001  | 0.028 |  -0.027/+0.027  |  -0.028/+0.027  |
# |   df   | 1.009  | 1.024  | 1.021  | 0.056 |  -0.055/+0.055  |  -0.060/+0.049  |
# |   dm   | -0.026 | -0.026 | -0.025 | 0.041 |  -0.040/+0.040  |  -0.036/+0.043  |
# |   b1   | 0.320  | 0.291  | 0.298  | 0.058 |  -0.056/+0.055  |  -0.042/+0.065  |
# |   b2   |  -1.9  |  -1.0  |  -1.0  |  1.6  |    -1.7/+1.7    |    -1.9/+1.6    |
# |   bs   |  0.9   |  1.1   |  1.1   |  2.1  |    -2.2/+2.3    |    -2.3/+2.2    |
# | alpha0 |   4    |   9    |   8    |  16   |     -16/+16     |     -17/+15     |
# ...
